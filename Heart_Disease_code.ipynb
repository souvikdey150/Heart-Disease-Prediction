# %% [markdown]
# # **1. Import The Libraries And Dataset**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# ⚫ age
#
# ⚫ sex
#
# ⚫ chest pain type (4 values)
#
#     Value 0: typical angina
#     Value 1: atypical angina
#     Value 2: non-anginal pain
#     Value 3: asymptomatic
#
# ⚫trestbps: resting blood pressure (in mm Hg on admission to the hospital)
#
# ⚫chol: serum cholestoral in mg/dl
#
# ⚫fbs: (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#
# ⚫ restecg: resting electrocardiographic results
#
#     Value 0: normal
#     Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#     Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
#
# ⚫thalach: maximum heart rate achieved
#
# ⚫exang: exercise induced angina (1=yes: 0 = no)
#
# ⚫oldpeak = ST depression induced by exercise relative to rest
#
# ⚫slope: the slope of the peak exercise ST segment
#
#     ■ Value 1: upsloping
#     ■ Value 2: flat
#     ■ Value 3: downsloping
#
# ⚫ca: number of major vessels (0-3) colored by flourosopy
#
# ⚫thal: 3 normal; 6 = fixed defect; 7= reversable defect
#
# ⚫target: O-less chance of heart attack, 1-more chance of heart attack**

# %% [markdown]
# # **2. Find Shape of Our Dataset (Number of Rows And Number of Columns)**

# %%
print('Number of Rows :',df.shape[0])
print('Number of Columns :',df.shape[1])
# Out:
# Number of Rows : 1025
# Number of Columns : 14

# %% [markdown]
# ⚫ Number of Rows : 1025
#
# ⚫ Number of Columns : 14

# %% [markdown]
# # **3. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement.**

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB
# None

# %% [markdown]
# **Here memory used 112.2KB and 1 column data type is float another 13 columns datatypes are int, all are 64 bit.**

# %% [markdown]
# # **4. Check Null Values In The Dataset.**

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# **Null value did't found in this dataset.**

# %% [markdown]
# # **5. Check For Duplicate Data and Drop Them.**

# %%
df_dup = df.duplicated().any()
print(df_dup)
df = df.drop_duplicates()
df.shape
# Out:
# True
# (302, 14)

# %% [markdown]
# **Here i got duplicate data.
# Then i will drop all duplicates data from dataset So, after drop duplicates values my row is 302 and columns is 14.**

# %% [markdown]
# # **6. Get Overall Statistics About The Dataset.**

# %%
df.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# **This is our Overall Statistics.**

# %% [markdown]
# # **7. Draw Correlation Matrix.**

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %% [markdown]
# **This is our Correlation Matrix**

# %%
 plt.figure(figsize=(17,6))
 sns.heatmap(df.corr(),annot = True)
 plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# **This is our Correlation Matrix figure using matplotlib**

# %% [markdown]
# # **8. How Many People Have Heart Disease, And How Many Don't Have Heart Disease In This Dataset?**

# %%
plt.figure(figsize=(14,6))
print(df['target'].value_counts())
sns.countplot(df['target']) 
plt.xticks([0,1],["Don't Have Heart Disease",'Heart Disease'])
plt.xticks(rotation = 75)
plt.title('Disease Plot')
plt.show()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **164 People Have Heart Disease, And 138 people Don't Have Heart Disease In This Dataset.**

# %% [markdown]
# # **9. Find Count of  Male & Female in this Dataset.**

# %%
df.columns
plt.figure(figsize=(14,6))
print(df['sex'].value_counts())
sns.countplot(df['sex'])
plt.xticks([0,1],['Female','Male'])
plt.title('Count of Male & Female')
plt.show()
# Out:
# 1    206
# 0     96
# Name: sex, dtype: int64
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Here male is 206 persons and female is 96.**

# %% [markdown]
# # **10. Find Gender Distribution According to The Target Variable.**

# %%
plt.figure(figsize=(17,6))
sns.countplot(x='sex',hue='target',data = df)
plt.xticks([0,1],['Female','Male'])
plt.title('Gender Distribution')
plt.legend(labels = ['No-Disease','Disease'])
plt.show()

# %% [markdown]
# **Here We have done gender distribution according to the target variable of male and female having heart disease and not having heart disease.**

# %% [markdown]
# # **11. Check Age Distribution In The Dataset.**

# %%
sns.displot(df['age'],bins = 20)
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# **age wise prediction plotchart according to the target value**

# %% [markdown]
# # **12. Check Chest Pain Type.**
#
# # chest pain type (4 values)
#
#     Value 0: typical angina
#     Value 1: atypical angina
#     Value 2: non-anginal pain
#     Value 3: asymptomatic

# %%
plt.figure(figsize=(17,6))
sns.countplot(x='sex',hue='cp',data = df)
plt.xticks([0,1],['Female','Male'])
plt.legend(labels = ['typical angina','atypical angina','non-anginal pain','asymptomatic'])
plt.ylabel('chest pain level')
plt.title('Chest Pain Type')
print(df['cp'].value_counts())
plt.show()
# Out:
# 0    143
# 2     86
# 1     50
# 3     23
# Name: cp, dtype: int64

# %% [markdown]
# **There are 143 typical angina patient( a type of chest pain caused by reduced blood flow to the heart. Angina is a symptom of coronary artery disease.),**
#
# **50 atypical angina patient(a heart attack may include fatigue, shortness of breath, discomfort in the throat, jaw, neck, arms, back and stomach),**
#
# **86 non-anginal pain patient(A chest pain is very likely nonanginal if its duration is over 30 minutes or less than 5 seconds, it increases with inspiration. local fingers pressure, or bending forward, or it can be relieved immediately on lying down.),**
#
# **23 asymptomatic patient(A silent heart attack is a heart attack that has few, if any, symptoms or has symptoms not recognized as a heart attack.).**

# %% [markdown]
# # **13. Show The Chest Pain Distribution As Per Target Variable**

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='cp',hue = 'target',data = df)
print(df['cp'].value_counts())
print(df['target'].value_counts())
plt.title('Chest Pain Distribution')
plt.legend(labels=['No-Disease','Disease'])
plt.show()
# Out:
# 0    497
# 2    284
# 1    167
# 3     77
# Name: cp, dtype: int64
# 1    526
# 0    499
# Name: target, dtype: int64

# %% [markdown]
# **Here we saw healthy people have Chest Pain Distribution As Per Target Variable**

# %% [markdown]
# # **14. Show Fasting Blood Sugar Distribution According To Target Variable.**

# %%
plt.figure(figsize=(14,6))
print(df['fbs'].value_counts())
sns.countplot(x='fbs',hue = 'target',data = df)
plt.xticks([0,1],['True','False'])
plt.title('Blood Sugar Distribution')
plt.legend(labels=['No-Disease','Disease'])
plt.show()
# Out:
# 0    872
# 1    153
# Name: fbs, dtype: int64

# %% [markdown]
# **This is Fasting Blood Sugar Distribution According To Target Variable.**

# %% [markdown]
# # **15. Which sex of people has more fasting blood sugar > 120 mg/dl?**

# %%
df.fbs.value_counts().plot(kind = 'pie', figsize = (8,9))
plt.legend(['fbs<120 mg/dl', 'fbs>120 mg/dl'])
plt.axis('equal')
exp_labels = ['sugar patients', 'without sugar patients']
plt.pie(df.fbs.value_counts(),labels = exp_labels,autopct="%1.2f%%",shadow =True)
pd.crosstab(df.sex, df.fbs)
pd.crosstab(df.sex, df.fbs).plot(kind = 'bar', color = ['lightblue','salmon'])
plt.title('Fasting blood sugar w.r.to sex')
plt.xlabel('0 = Female, 1 = Male')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # **16.  Age vs serum cholestoral when people have heart disease or doesn't have heart disease.**

# %%
plt.figure(figsize = (10,6))
plt.scatter(df.age[df.target == 1],
            df.chol[df.target == 1],
            c = 'red')
plt.scatter(df.age[df.target == 0],
            df.chol[df.target == 0],
            c = 'blue')
plt.title('Serum Cholestroral vs age')
plt.xlabel('Age')
plt.ylabel('Serum Cholestroral')
plt.legend(['Disease', 'No disease'])
plt.show()

# %% [markdown]
# # **17. People of which sex has more exercise induced angina?**

# %%
df.head(10)
plt.figure(figsize = (10,6))
sns.countplot(x = 'sex', hue = 'exang',data = df)
plt.title('Exercise induced angina w.r.to sex')
plt.legend(labels=['No','YES'])
plt.show()

# %% [markdown]
# **In this graphs shows 0 menas how many of them not having exercise induced angina and 1 means how many of them having exercise induced angina**

# %% [markdown]
# # **18.  Check Resting Blood Pressure Distribution**

# %%
plt.figure(figsize=(14,6))
df['trestbps'].hist()
plt.xlabel('Blood Pressure level')
plt.ylabel('Age')
plt.title('Blood Pressure Distribution')
plt.show()

# %% [markdown]
# **Here we check Resting Blood Pressure Distribution according to the age of both male and female using histogram.**

# %% [markdown]
# # **19. Show Distribution of Serum cholesterol**

# %%
plt.figure(figsize=(14,6))
df['chol'].hist()
plt.xlabel('Serum cholesterol level')
plt.title('Distribution of Serum cholesterol')
plt.show()

# %% [markdown]
# **Here we check the level of Serum cholesterol as per age**

# %% [markdown]
# ## **20. Compare Resting Blood Pressure As Per Sex Column**

# %%
g = sns.FacetGrid(df,hue='sex',aspect = 4)
g.map(sns.kdeplot,'trestbps',shade = True)
plt.legend(labels = ['Male','Female'])

# %% [markdown]
# # **21. Plot Continuous Variables**

# %%
cate_value=[]
cont_value=[]

for column in df.columns:
  if df[column].nunique()  <=10:
    cate_value.append(column)
  else:
    cont_value.append(column)

# %%
df.hist(cont_value,figsize=(14,6))
plt.tight_layout()
plt.show()

# %% [markdown]
# # **22. Plot Categorical Variables.**

# %%
df.hist(cate_value,figsize=(14,6))
plt.tight_layout()
plt.show()
